# %%
import os
os.chdir('..')
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
from Preprocessing import MatchAnalyzer as ma
from Database import FootballDB

# %% [markdown]
# 1. DB 인스턴스 생성

# %%
# db = FootballDB('localhost', 'postgres', 5432, 'udmt', 'football')
db = FootballDB('localhost', 'postgres', 5432, 'alsdud12', 'football')

# %% [markdown]
# 2.  Season Table 불러오기

# %%
query = "SELECT * FROM tbl_season_position WHERE season='17-18'"
rows, cols = db.selectResult(query)
result = pd.DataFrame(data=rows, columns=cols)
result
# Out:
#             league season  position            team  point  won  drawn  lost  \
# 0   Premier League  17-18         1        Man City    100   32      4     2
# 1   Premier League  17-18         2      Man United     81   25      6     7
# 2   Premier League  17-18         3       Tottenham     77   23      8     7
# 3   Premier League  17-18         4       Liverpool     75   21     12     5
# 4   Premier League  17-18         5         Chelsea     70   21      7    10
# 5   Premier League  17-18         6         Arsenal     63   19      6    13
# 6   Premier League  17-18         7         Burnley     54   14     12    12
# 7   Premier League  17-18         8         Everton     49   13     10    15
# 8   Premier League  17-18         9       Leicester     47   12     11    15
# 9   Premier League  17-18        10       Newcastle     44   12      8    18
# 10  Premier League  17-18        11  Crystal Palace     44   11     11    16
# ...

# %%
query = "SELECT * FROM tbl_season_position WHERE season='18-19'"
rows, cols = db.selectResult(query)
result = pd.DataFrame(data=rows, columns=cols)
result
# Out:
#             league season  position            team  point  won  drawn  lost  \
# 0   Premier League  18-19         1        Man City     98   32      2     4
# 1   Premier League  18-19         2       Liverpool     97   30      7     1
# 2   Premier League  18-19         3         Chelsea     72   21      9     8
# 3   Premier League  18-19         4       Tottenham     71   23      2    13
# 4   Premier League  18-19         5         Arsenal     70   21      7    10
# 5   Premier League  18-19         6      Man United     66   19      9    10
# 6   Premier League  18-19         7          Wolves     57   16      9    13
# 7   Premier League  18-19         8         Everton     54   15      9    14
# 8   Premier League  18-19         9       Leicester     52   15      7    16
# 9   Premier League  18-19        10        West Ham     52   15      7    16
# 10  Premier League  18-19        11         Watford     50   14      8    16
# ...

# %%
query = "SELECT * FROM tbl_season_position WHERE season='16-17'"
rows, cols = db.selectResult(query)
result = pd.DataFrame(data=rows, columns=cols)
result
# Out:
#             league season  position            team  point  won  drawn  lost  \
# 0   Premier League  16-17         1         Chelsea     93   30      3     5
# 1   Premier League  16-17         2       Tottenham     86   26      8     4
# 2   Premier League  16-17         3        Man City     78   23      9     6
# 3   Premier League  16-17         4       Liverpool     76   22     10     6
# 4   Premier League  16-17         5         Arsenal     75   23      6     9
# 5   Premier League  16-17         6      Man United     69   18     15     5
# 6   Premier League  16-17         7         Everton     61   17     10    11
# 7   Premier League  16-17         8     Southampton     46   12     10    16
# 8   Premier League  16-17         9     Bournemouth     46   12     10    16
# 9   Premier League  16-17        10       West Brom     45   12      9    17
# 10  Premier League  16-17        11        West Ham     45   12      9    17
# ...
